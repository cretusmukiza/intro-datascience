# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
x = np.arange(2,10,2)

# %%
x
# Out:
# array([2, 4, 6, 8])

# %%
y = np.arange(42,50,2)

# %%
y
# Out:
# array([42, 44, 46, 48])

# %%
plt.plot(x,y)

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot()

# %%
fig = plt.figure()

# %%
ax = fig.add_axes([1,1,1,1])

# %%
# %matplotlib inline
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(x,y)
ax.set(title="Sample Graph",xlabel="x-axis",ylabel="y-axis")
fig.savefig("images/sample-plot.png")

# %%
x = np.linspace(0,50,100)
fig,ax = plt.subplots()
ax.plot(x,x**2)

# %%
fig,ax = plt.subplots()
ax.scatter(x,np.exp(x))

# %%
fig,ax = plt.subplots()
ax.scatter(x,np.sin(x))

# %%
fig,ax = plt.subplots()
ax.bar(["a","e","i"],[1,2,4])
ax.set(title="range")
# Out:
# [Text(0.5, 1.0, 'range')]

# %%
fig,ax = plt.subplots()
ax.barh(["a","e","i"],[1,2,4])
ax.set(title="range")
# Out:
# [Text(0.5, 1.0, 'range')]

# %%
x = np.random.randn(1000)
fig,ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  5.,  20.,  71., 129., 237., 243., 179.,  84.,  27.,   5.]),
#  array([-3.24426309, -2.61546061, -1.98665814, -1.35785566, -0.72905319,
#         -0.10025071,  0.52855176,  1.15735424,  1.78615671,  2.41495919,
#          3.04376166]),
#  <a list of 10 Patch objects>)

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(np.random.randint(100,size=(20,)))
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(["a","e","i"],[80,90,100])
ax4.hist(np.random.randn(100))
# Out:
# (array([ 3.,  6.,  5.,  8., 18., 21., 17., 15.,  2.,  5.]),
#  array([-2.88223126, -2.35584566, -1.82946006, -1.30307446, -0.77668886,
#         -0.25030327,  0.27608233,  0.80246793,  1.32885353,  1.85523913,
#          2.38162473]),
#  <a list of 10 Patch objects>)

# %%
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(np.random.randint(10,size=(10,)),np.random.random(10))
ax[1,1].hist(np.random.randint(10,size=(10,)))
# Out:
# (array([2., 0., 0., 0., 0., 4., 0., 1., 1., 2.]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. , 4.8, 5.6, 6.4, 7.2, 8. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Ploting DataFrame

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),index = pd.date_range('1/1/2010',periods=1000))

# %%
ts
# Out:
# 2010-01-01   -1.090558
# 2010-01-02    0.587716
# 2010-01-03   -0.488364
# 2010-01-04    1.115265
# 2010-01-05   -0.407299
#                 ...
# 2012-09-22    1.231583
# 2012-09-23    0.326160
# 2012-09-24    0.931610
# 2012-09-25   -0.741957
# 2012-09-26   -0.299607
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]','').astype("float")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales['Sale Date'] = pd.date_range('1/1/2020',periods=10)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date
# 0  Toyota  White         150043      4   4000.0 2020-01-01
# 1   Honda    Red          87899      4   5000.0 2020-01-02
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03
# 3     BMW  Black          11179      5  22000.0 2020-01-04
# 4  Nissan  White         213095      4   3500.0 2020-01-05
# 5  Toyota  Green          99213      4   4500.0 2020-01-06
# 6   Honda   Blue          45698      4   7500.0 2020-01-07
# 7   Honda   Blue          54738      4   7000.0 2020-01-08
# 8  Toyota  White          60000      4   6250.0 2020-01-09
# 9  Nissan  White          31600      4   9700.0 2020-01-10

# %%
car_sales['Total Sales'] = car_sales['Price'].cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2020-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2020-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2020-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2020-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2020-01-10      76450.0

# %%
car_sales.plot(x="Sale Date",y="Total Sales")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2020-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2020-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2020-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2020-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2020-01-10      76450.0

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")

# %%
x = np.random.randn(10,4)

# %%
x
# Out:
# array([[ 0.41843125, -0.49868852,  0.14445406,  0.92285333],
#        [-0.63084575, -1.07003138,  1.05650439,  0.6757479 ],
#        [ 0.85587687, -0.04305019, -0.0443945 , -0.36788625],
#        [ 0.8002797 , -0.81916878, -0.13525608, -0.23149103],
#        [-1.27194674,  0.95026724, -0.72081065, -0.19396641],
#        [ 0.28306755,  1.37701232,  0.7684463 , -1.16980788],
#        [-0.50594519,  1.63638299,  0.75605639, -2.32757647],
#        [ 1.46182332,  0.76938368,  0.29629515,  0.9150804 ],
#        [-0.33452374, -0.45103625,  0.73232585,  1.15760507],
#        [-0.35933   , -1.03392818, -0.53201957,  0.28173164]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.418431 -0.498689  0.144454  0.922853
# 1 -0.630846 -1.070031  1.056504  0.675748
# 2  0.855877 -0.043050 -0.044394 -0.367886
# 3  0.800280 -0.819169 -0.135256 -0.231491
# 4 -1.271947  0.950267 -0.720811 -0.193966
# 5  0.283068  1.377012  0.768446 -1.169808
# 6 -0.505945  1.636383  0.756056 -2.327576
# 7  1.461823  0.769384  0.296295  0.915080
# 8 -0.334524 -0.451036  0.732326  1.157605
# 9 -0.359330 -1.033928 -0.532020  0.281732

# %%
df.plot.bar()

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2020-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2020-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2020-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2020-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2020-01-10      76450.0

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar");

# %%
car_sales["Odometer (KM)"].plot.hist()

# %%
heart_disease = pd.read_csv('heart-disease.csv')

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=50)

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %%
over_50 = heart_disease[heart_disease["age"] > 50]

# %%
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
heart_disease.groupby(['age']).sum()
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 29     1   1       130   204    0        0      202      0      0.0      2
# 34     1   4       236   392    0        1      366      0      0.7      4
# 35     3   1       506   855    0        3      642      2      3.0      7
# 37     1   4       250   465    0        2      357      0      3.5      2
# 38     3   7       396   581    0        3      528      1      3.8      5
# 39     2   6       490   959    0        3      653      0      1.2      6
# 40     3   3       402   589    0        2      473      2      3.4      5
# 41     6  12      1190  2207    0        6     1647      1      3.4     18
# 42     6  10      1016  1974    1        6     1282      1      4.0     11
# 43     6   4      1011  2054    2        5     1239      3     10.4     11
# 44     9  13      1328  2435    0        7     1857      2      4.1     18
# ...

# %%
over_50.plot(kind="scatter",x="age",y="chol",c="target");

# %%
fig,ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",x="age",y="chol",c="target",ax=ax);
ax.set_xlim([45,100])
# Out:
# (45.0, 100.0)

# %%
## oo method from the scratch
fig,ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50['age'],y=over_50['chol'],c=over_50['target']);
ax.set(title="Heart Disease and Cholesterol Levels",xlabel="Age",ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(),title="Target");
ax.axhline(over_50['chol'].mean(),linestyle="--");

# %%
fig,(ax0,ax1) = plt.subplots(nrows=2,ncols=1,figsize=(10,10))
scatter0 = ax0.scatter(x=over_50['age'],y=over_50['chol'],c=over_50['target'],cmap="winter");
ax0.set(xlabel="Age",ylabel="Cholesterol",title="Heart Disease and Cholesterol Levels");
ax0.set_xlim([50,80]);
ax0.set_ylim([60,400]);
ax0.legend(*scatter0.legend_elements(),title="Target");
ax0.axhline(y=over_50["chol"].mean(),linestyle="--");

# Figure 2
scatter1 = ax1.scatter(x=over_50['age'],y=over_50['thalach'],c=over_50['target'],cmap="winter");
ax1.set(title="Heart Disease and Max Heart Rate",xlabel="Age",ylabel="Max Heart Rate");
ax1.set_xlim([50,80]);
ax1.set_ylim([60,400]);
ax1.legend(*scatter1.legend_elements(),title="Target");
ax1.axhline(over_50['thalach'].mean(),linestyle="--");
fig.suptitle("Heart Disease Analysis",fontsize="16",fontweight="bold");

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales['Price'].plot();

# %%
car_sales.plot(y="Price",x="Odometer (KM)",kind="scatter");

# %%
plt.style.use('ggplot')

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar");

# %%
df
# Out:
#           a         b         c         d
# 0  0.418431 -0.498689  0.144454  0.922853
# 1 -0.630846 -1.070031  1.056504  0.675748
# 2  0.855877 -0.043050 -0.044394 -0.367886
# 3  0.800280 -0.819169 -0.135256 -0.231491
# 4 -1.271947  0.950267 -0.720811 -0.193966
# 5  0.283068  1.377012  0.768446 -1.169808
# 6 -0.505945  1.636383  0.756056 -2.327576
# 7  1.461823  0.769384  0.296295  0.915080
# 8 -0.334524 -0.451036  0.732326  1.157605
# 9 -0.359330 -1.033928 -0.532020  0.281732

# %%
df.plot(kind="bar")

# %%
ax = df.plot(kind="bar");
ax.set(title="Bar Graph from Random Numbers")
ax.legend().set_visible(True)

# %%
## oo method from the scratch
plt.style.use('seaborn-whitegrid')
fig,ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50['age'],y=over_50['chol'],c=over_50['target'],cmap="winter");
ax.set(title="Heart Disease and Cholesterol Levels",xlabel="Age",ylabel="Cholesterol");
ax.legend(scatter.legend_elements(),title="Target");
ax.axhline(over_50['chol'].mean(),linestyle="--");
